# %% [markdown]
# <a href="https://colab.research.google.com/github/Vamsikrishna2427/FMML_MODULE1/blob/main/Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-15 02:50:30--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   309MB/s    in 0.2s
#
# 2025-03-15 02:50:32 (309 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 39660  1611.08841v2  Boundary estimation in images and videos has b...    cs
# 22746  1705.09046v2  Exponential family distributions are highly us...  stat
# 22222  1508.07535v1  A general approach for anomaly detection or no...  stat
# 21571   1103.0431v2  We investigate the learning rate of multiple k...  stat
# 13993  1704.00764v2  The convolutional neural network (CNN), which ...    cs
# ...             ...                                                ...   ...
# 11089   1404.6216v1  The term "CoRE kernel" stands for correlation-...  stat
# 4682    0808.3231v4  In this paper, we propose the MIML (Multi-Inst...    cs
# 15458  1506.01914v1  The quality and quantity of articles in each W...    cs
# 10547   1207.6083v4  Determinantal point processes (DPPs) are elega...  stat
# 21948  1612.08915v1  In typical applications of Bayesian optimizati...  stat
#
#                                                    title  year  \
# 39660                Long-Term Image Boundary Prediction  2016
# 22746  Expectation Propagation for t-Exponential Fami...  2017
# 22222  Calibration of One-Class SVM for MV set estima...  2015
# 21571  Fast Convergence Rate of Multiple Kernel Learn...  2011
# 13993  A Genetic Programming Approach to Designing Co...  2017
# ...                                                  ...   ...
# 11089                                       CoRE Kernels  2014
# 4682                 Multi-Instance Multi-Label Learning  2008
# 15458  Content Translation: Computer-assisted transla...  2015
# 10547  Determinantal point processes for machine lear...  2012
# 21948       Bayesian Optimization with Shape Constraints  2016
#
#                                                 keywords
# 39660  [estimation, organizing, information, boundari...
# 22746  [exponential, distributions, calculation, perf...
# 22222  [detection, detection, estimating, algorithm, ...
# 21571  [investigate, regularization, regularizer, reg...
# 13993  [convolutional, designing, architectures, know...
# ...                                                  ...
# 11089  [correlation, resemblance, applications, dimen...
# 4682   [framework, described, instances, associated, ...
# 15458  [wikipedia, translating, wikipedia, translatio...
# 10547  [determinantal, processes, probabilistic, repu...
# 21948  [applications, optimization, assumptions, obje...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 39660    [estimation, organizing, information, boundari...
# 22746    [exponential, distributions, calculation, perf...
# 22222    [detection, detection, estimating, algorithm, ...
# 21571    [investigate, regularization, regularizer, reg...
# 13993    [convolutional, designing, architectures, know...
#                                ...
# 27201    [investigation, techniques, handwritten, chara...
# 11723    [understanding, applications, aggregate, trans...
# 29895    [techniques, successfully, representation, dif...
# 6123     [polynomial, factorization, efficiently, inter...
# 19944    [presented, probabilistic, uncertainty, effici...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8863 words.
# Out of those 4594 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="54bef8a5-8dfa-40b4-8dec-6e19e3ce8481" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("54bef8a5-8dfa-40b4-8dec-6e19e3ce8481")) {                    Plotly.newPlot(                        "54bef8a5-8dfa-40b4-8dec-6e19e3ce8481",                        [{"x":["estimation","intuitive","organizing","estimating","predicting","experiment","sequences","synthetic","boundaries","deterministic","predictions","perception","including","unobserved","prediction","corresponding","information","parameters","expectation","posterior","numerically","approximation","distribution","statistical","algorithm","distributions","calculation","performance","mathematical","propagation","predictive","additivity","performed","efficient","exponential","efficiently","demonstrate","proportion","parameter","limitations","sensitive","estimates","hyperparameters","selection","different","detection","calibration","presented","outperforms","automatically","overfitting","unsupervised","dimensionality","traintest","aggregated","probability","formulation","dimensional","suffering","practical","experimental","adjusting","controlling","smoothness","relatively","regularizer","convergence","investigate","regularization","components","functional","architecture","convolutional","functions","cartesian","architectures","classification","connectivity","represented","constructed","optimized","structure","concatenation","programming","knowledge","validation","designing","construct","competitive","combining","implemented","collected","inference","parametric","switching","scenarios","inferring","equivalently","methodology","simulated","sequential","mechanistic","formulated","probabilistic","resulting","reformulated","principles","illustrate","formulating","environment","underlying","evaluated","representation","independent","compositional","traditional","separated","requiring","embeddings","separation","encourage","procedure","determine","discovery","formalize","describes","embedding","dimensions","properties","categories","statistic","alternative","interpretable","procedures","factorial","representations","disentangled","modularity","discovering","approaches","disentangling","generalizable","experiments","translation","enrichment","augmenting","distributed","evaluation","approximate","framework","resources","reference","interesting","automatic","augmented","available","additional","morphological","currently","languages","consuming","providing","representing","parallelism","typically","recursion","significant","increased","represent","expressivity","desirable","streaming","expressed","integrating","supporting","processing","expressive","execution","accomplished","supported","integrated","specifically","operators","dependencies","conducted","potential","generalize","influence","applicable","situation","comprehensive","comparison","respectively","recurrent","advantage","monitoring","effectiveness","classifier","specially","compositions"],"y":[192,39,26,59,93,80,107,143,31,55,76,47,249,6,218,119,689,234,32,42,11,114,205,149,843,116,23,928,55,64,44,2,116,414,53,154,546,7,118,60,48,72,13,158,714,324,14,185,262,171,24,149,56,1,12,165,73,176,4,147,366,3,12,16,60,17,110,149,82,98,22,253,355,229,8,145,502,15,102,55,59,329,5,124,354,53,47,78,115,106,110,67,235,42,6,85,24,3,93,61,98,2,40,174,140,7,35,69,11,119,127,147,343,127,28,169,7,42,72,26,21,93,67,62,15,85,100,39,203,91,9,100,27,28,2,234,5,9,26,448,5,9,627,113,5,16,110,264,119,526,69,54,71,212,29,268,111,28,55,98,36,84,71,20,99,4,225,36,107,8,40,19,36,46,20,309,40,28,4,19,56,177,33,63,80,160,57,55,49,34,78,130,97,141,108,31,189,160,6,6],"type":"bar"},{"x":["estimation","intuitive","organizing","estimating","predicting","experiment ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4594,), (4594, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8075

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>An</span> <span style=''>Online</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Universal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Classifier</span> <span style=''>for</span> <span style=''>Binary</span> <span style=''>Multi</span> <span style=''>class</span> <span style=''>and</span> <span style=''>Multi</span> <span style=''>label</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Classification</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Classification</span> <span style=''>involves</span> <span style=''>the</span> <span style=''>learning</span> <span style=''>of</span> <span style=''>the</span> <span style=''>mapping</span> <span style=''>function</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666666);'>associates</span> <span style=''>input</span> <span style=''>samples</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponding</span> <span style=''>target</span> <span style=''>label</span> <span style=''>There</span> <span style=''>are</span> <span style=''>two</span> <span style=''>major</span> <span style='background-color:rgba(0, 255, 0, 0.5689655172413792);'>categories</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>problems</span> <span style=''>Single</span> <span style=''>label</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>and</span> <span style=''>Multi</span> <span style=''>label</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style='background-color:rgba(0, 255, 0, 0.33596837944664015);'>Traditional</span> <span style=''>binary</span> <span style=''>and</span> <span style=''>multi</span> <span style=''>class</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>classifications</span> <span style=''>are</span> <span style=''>sub</span> <span style='background-color:rgba(0, 255, 0, 0.5689655172413792);'>categories</span> <span style=''>of</span> <span style=''>single</span> <span style=''>label</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>Several</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developed</span> <span style=''>for</span> <span style=''>binary</span> <span style=''>multi</span> <span style=''>class</span> <span style=''>and</span> <span style=''>multi</span> <span style=''>label</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>problems</span> <span style=''>but</span> <span style=''>there</span> <span style=''>are</span> <span style=''>no</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>available</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>literature</span> <span style=''>capable</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performing</span> <span style=''>all</span> <span style=''>three</span> <span style=''>types</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>online</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>universal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>capable</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performing</span> <span style=''>all</span> <span style=''>the</span> <span style=''>three</span> <span style=''>types</span> <span style=''>o ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimating</span> <span style=''>β</span> <span style=''>mixing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coefficients</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>learning</span> <span style=''>for</span> <span style=''>time</span> <span style=''>series</span> <span style=''>assumes</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>asymptotic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independence</span> <span style=''>or</span> <span style=''>mixing</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generating</span> <span style=''>process</span> <span style=''>These</span> <span style=''>mixing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>are</span> <span style=''>never</span> <span style=''>tested</span> <span style=''>nor</span> <span style=''>are</span> <span style=''>there</span> <span style=''>methods</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>mixing</span> <span style=''>rates</span> <span style=''>from</span> <span style=''>data</span> <span style=''>We</span> <span style=''>give</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>for</span> <span style=''>the</span> <span style=''>beta</span> <span style=''>mixing</span> <span style=''>rate</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>single</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stationary</span> <span style=''>sample</span> <span style=''>path</span> <span style=''>and</span> <span style=''>show</span> <span style=''>it</span> <span style=''>is</span> <span style=''>L</span> <span style=''>1</span> <span style=''>risk</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistent</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Towards</span> <span style=''>Optimal</span> <span style=''>One</span> <span style=''>Pass</span> <span style=''>Large</span> <span style=''>Scale</span> <span style=''>Learning</span> <span style=''>with</span> <span style=''>Averaged</span> <span style='background-color:rgba(255, 0, 0, 0.3168316831683168);'>Stochastic</span> <span style=''>Gradient</span> <span style=''>Descent</span> <br/><br/><span style=''>For</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>desirable</span> <span style=''>if</span> <span style=''>we</span> <span style=''>can</span> <span style=''>obtain</span> <span style=''>the</span> <span style=''>optimal</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>by</span> <span style=''>going</span> <span style=''>through</span> <span style=''>the</span> <span style=''>data</span> <span style=''>in</span> <span style=''>only</span> <span style=''>one</span> <span style=''>pass</span> <span style=''>Polyak</span> <span style=''>and</span> <span style=''>Juditsky</span> <span style=''>(1992)</span> <span style=''>showed</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>asymptotically</span> <span style=''>the</span> <span style=''>test</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>the</span> <span style=''>simple</span> <span style=''>average</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>obtained</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3168316831683168);'>stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>(SGD)</span> <span style=''>is</span> <span style=''>as</span> <span style=''>good</span> <span style=''>as</span> <span style=''>that</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>which</span> <span style=''>minimize</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>cost</span> <span style=''>However</span> <span style=''>to</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3964497041420119);'>knowledge</span> <span style=''>despite</span> <span style=''>its</span> <span style=''>optimal</span> <span style='background-color:rgba(255, 0, 0, 0.6869565217391305);'>asymptotic</span> <span style='background-color:rgba(255, 0, 0, 0.36962750716332377);'>convergence</span> <span style=''>rate</span> <span style=''>averaged</span> <span style=''>SGD</span> <span style=''>(ASGD)</span> <span style=''>received</span> <span style=''>little</span> <span style='background-color:rgba(0, 255, 0, 0.3464566929133859);'>attention</span> <span style=''>in</span> <span style=''>recent</span> <span style=''>research</span> <span style=''>on</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>learning</span> <span style=''>One</span> <span style=''>possible</span> <span style=''>reason</span> <span style=''>is</span> <span style=''>that</span> <span style=''>it</span> <span style=''>may</span> <span style=''>take</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prohibitively</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style=''>training</span> <span style=''>samples</span> <span style=''>for</span> <span style=''>ASGD</span> <span style=''>to</span> <span style=''>reach</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.6869565217391305);'>asymptotic</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Top</span> <span style=''>k</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Multiclass</span> <span style=''>SVM</span> <br/><br/><span style=''>Class</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>ambiguity</span> <span style=''>is</span> <span style=''>typical</span> <span style=''>in</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>problems</span> <span style=''>with</span> <span style=''>a</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style=''>classes</span> <span style=''>When</span> <span style=''>classes</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminate</span> <span style=''>it</span> <span style=''>makes</span> <span style=''>sense</span> <span style=''>to</span> <span style=''>allow</span> <span style=''>k</span> <span style=''>guesses</span> <span style=''>and</span> <span style=''>evaluate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>top</span> <span style=''>k</span> <span style=''>error</span> <span style=''>instead</span> <span style=''>of</span> <span style=''>the</span> <span style=''>standard</span> <span style=''>zero</span> <span style=''>one</span> <span style=''>loss</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>top</span> <span style=''>k</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multiclass</span> <span style=''>SVM</span> <span style=''>as</span> <span style=''>a</span> <span style=''>direct</span> <span style=''>method</span> <span style=''>to</span> <span style=''>optimize</span> <span style=''>for</span> <span style=''>top</span> <span style=''>k</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style=''>the</span> <span style=''>well</span> <span style=''>known</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multiclass</span> <span style=''>SVM</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>tight</span> <span style=''>convex</span> <span style=''>upper</span> <span style=''>bound</span> <span style=''>of</span> <span style=''>the</span> <span style=''>top</span> <span style=''>k</span> <span style=''>error</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>fast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>scheme</span> <span style=''>based</span> <span style=''>on</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>projection</span> <span style=''>onto</span> <span style=''>the</span> <span style=''>top</span> <span style=''>k</span> <span style=''>simplex</span> <span style=''>which</span> <span style=''>is</span> <span style=''>of</span> <span style=''>its</span> <span style=''>own</span> <span style=''>interest</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Experiments</span> <span style=''>on</span> <span style=''>five</span> <span style=''>datasets</span> <span style=''>show</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improvements</span> <span style=''>in</span> <span style=''>top</span> <span style=''>k</span> <span style=''>accuracy</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>various</span> <span style='background-color:rgba(255, 0, 0, 0.3); ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.0906485130777499)
# 	automatic (0.07595843783590112)
# 	knowledge (0.1268362594052311)
# 	processing (0.1107130060910068)
# 	segmentation (0.07273378717305626)
# 	detection (0.1160874238624149)
# 	information (0.2468649229666786)
# 	different (0.25582228591902545)
# 	convolutional (0.12719455392332496)
# 	recognition (0.1390182730204228)
#
# Some Statistics words are:
# 	algorithm (0.3827775012444002)
# 	stochastic (0.13240418118466898)
# 	theoretical (0.14982578397212543)
# 	variables (0.13937282229965156)
# 	statistical (0.15430562468889994)
# 	estimation (0.1712294673967148)
# 	distribution (0.17670482827277254)
# 	inference (0.1916376306620209)
# 	dimensional (0.19263315082130414)
# 	regression (0.18068690890990544)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="73ccf152-ccbe-4aff-903c-21c7c71c5e24" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73ccf152-ccbe-4aff-903c-21c7c71c5e24")) {                    Plotly.newPlot(                        "73ccf152-ccbe-4aff-903c-21c7c71c5e24",                        [{"x":["estimation","intuitive","organizing","estimating","predicting","experiment","sequences","synthetic","boundaries","deterministic","predictions","perception","including","unobserved","prediction","corresponding","information","parameters","expectation","posterior","numerically","approximation","distribution","statistical","algorithm","distributions","calculation","performance","mathematical","propagation","predictive","additivity","performed","efficient","exponential","efficiently","demonstrate","proportion","parameter","limitations","sensitive","estimates","hyperparameters","selection","different","detection","calibration","presented","outperforms","automatically","overfitting","unsupervised","dimensionality","traintest","aggregated","probability","formulation","dimensional","suffering","practical","experimental","adjusting","controlling","smoothness","relatively","regularizer","convergence","investigate","regularization","components","functional","architecture","convolutional","functions","cartesian","architectures","classification","connectivity","represented","constructed","optimized","structure","concatenation","programming","knowledge","validation","designing","construct","competitive","combining","implemented","collected","inference","parametric","switching","scenarios","inferring","equivalently","methodology","simulated","sequential","mechanistic","formulated","probabilistic","resulting","reformulated","principles","illustrate","formulating","environment","underlying","evaluated","representation","independent","compositional","traditional","separated","requiring","embeddings","separation","encourage","procedure","determine","discovery","formalize","describes","embedding","dimensions","properties","categories","statistic","alternative","interpretable","procedures","factorial","representations","disentangled","modularity","discovering","approaches","disentangling","generalizable","experiments","translation","enrichment","augmenting","distributed","evaluation","approximate","framework","resources","reference","interesting","automatic","augmented","available","additional","morphological","currently","languages","consuming","providing","representing","parallelism","typically","recursion","significant","increased","represent","expressivity","desirable","streaming","expressed","integrating","supporting","processing","expressive","execution","accomplished","supported","integrated","specifically","operators","dependencies","conducted","potential","generalize","influence","applicable","situation","comprehensive","comparison","respectively","recurrent","advantage","monitoring","effectiveness","classifier","specially","compositions","frequency","structural","precision","actigraphy","bidirectional","signatures","characterization","coincides","particular","characterizations","semantics","prominent","identifying","substitutes","simplified","propositional","grounding","optimization","treatment","equivalence","comparisons","equivalences","characterized","quantified","selections","minorizes","assumption","transforms","psychological","generalized","euclidean","computable","arbitrary","algorithmic","generalization","nonetheless","universal","confusion","mathematically","probabilities","appealing","multidimensional","processes","superiority","empirically","construction","explicitly","reproducing","respective","classifications","fundamental","suggested","confirmed","criterion","attr ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	actigraphy
# 	compromised
# 	reassignment
# 	durations
# 	differentiability
# 	semiparametric
# 	martingales
# 	hypersphere
# 	distributionally
# 	geodesics
# 	censoring
# 	variationally
# 	tolerates
# 	epileptic
# 	misclassify
# 	economics
# 	infinitesimal
# 	heartbeats
# 	concordance
# 	assimilation
# Some words which never appear in Statistics papers:
# 	concatenation
# 	mechanistic
# 	reformulated
# 	enrichment
# 	propositional
# 	grounding
# 	minorizes
# 	automaton
# 	accepting
# 	forbidden
# 	unpredictable
# 	treadmill
# 	distinctiveness
# 	predicates
# 	sensorimotor
# 	eligibility
# 	discipline
# 	implementable
# 	judgement
# 	outputting

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.076544425301501e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7666666666666667
